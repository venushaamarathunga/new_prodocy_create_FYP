# %%
# !pip install pickle-mixin

# %%
import parselmouth
from parselmouth.praat import call, run_file
import glob
import pandas as pd
import numpy as np
import scipy
from scipy.stats import binom
from scipy.stats import ks_2samp
from scipy.stats import ttest_ind
import os
import pickle
import matplotlib.pyplot as plt

# %%
p = r"E:/jupyter_project/FYP_1.1_pro"

# %%
def run_praat_file(p):
    
    arrarOfData = []
    
    dir_lists = os.listdir('myprosody/dataset/audioFiles/')
    # print(dir_lists)
    for dir_list in dir_lists:
        file_format = dir_list.split('.')[1]
    #     print(file_format)
        if(file_format == "wav"):
            m = dir_list.split('.')[0]
            sound=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"+m+".wav"
            sourcerun=p+"/"+"myprosody"+"/"+"dataset"+"/"+"essen"+"/"+"myspsolution.praat"
            path=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"

            try:
                objects= run_file(sourcerun, -20, 2, 0.3, "yes",sound,path, 80, 400, 0.01, capture_output=True)
#                 print (objects[0]) # This will print the info from the sound object, and objects[0] is a parselmouth.Sound object
                z1=str( objects[1]) # This will print the info from the textgrid object, and objects[1] is a parselmouth.Data object with a TextGrid inside
                z2=z1.strip().split()
                z3=int(z2[13]) # will be the integer number 10
                z4=float(z2[14]) # will be the floating point number 8.3
                db= binom.rvs(n=10,p=z4,size=10000)
                a=np.array(db)
                b=np.mean(a)*100/10
                del z2[-1]
                aaa = str(dir_list)
                z2.append(format(b,'.2f'))
                z2.append(aaa)
                arrarOfData.append(z2)
#                 print (dataset.T)
            except:
                print ("Try again the sound of the audio was not clear")
    dff = pd.DataFrame(arrarOfData,columns=("number_of_syllables","number_of_pauses","rate_of_speech","articulation_rate","speaking_duration","original_duration","balance","f0_mean","f0_std","f0_median","f0_min","f0_max","f0_quantile25","f0_quan75","Pronunciation_score_percentage","name_of_audio"))
#     print(arrarOfData)
    dff.to_csv('my_new_file.csv',index=False)

# %%
run_praat_file(p)

# %%
def mysptotal(p):
    """
    Overview
    """
    dir_list = os.listdir('myprosody/dataset/audioFiles/')
    # print(dir_list)
    for dir_list in dir_list:
        file_format = dir_list.split('.')[1]
    #     print(file_format)
        if(file_format == "wav"):
            m = dir_list.split('.')[0]
            sound=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"+m+".wav"
            sourcerun=p+"/"+"myprosody"+"/"+"dataset"+"/"+"essen"+"/"+"myspsolution.praat"
            path=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"
            
            try:
                objects= run_file(sourcerun, -20, 2, 0.3, "yes",sound,path, 80, 400, 0.01, capture_output=True)
#                 print (objects[0]) # This will print the info from the sound object, and objects[0] is a parselmouth.Sound object
                z1=str( objects[1]) # This will print the info from the textgrid object, and objects[1] is a parselmouth.Data object with a TextGrid inside
                z2=z1.strip().split()          
                z3=np.array(z2)
                z4=np.array(z3)[np.newaxis]
                z5=z4.T
                dataset=pd.DataFrame({"name_of_audio":m,"number_ of_syllables":z5[0,:],"number_of_pauses":z5[1,:],"rate_of_speech":z5[2,:],"articulation_rate":z5[3,:],"speaking_duration":z5[4,:],
                        "original_duration":z5[5,:],"balance":z5[6,:],"f0_mean":z5[7,:],"f0_std":z5[8,:],"f0_median":z5[9,:],"f0_min":z5[10,:],"f0_max":z5[11,:],
                        "f0_quantile25":z5[12,:],"f0_quan75":z5[13,:]})
                print (dataset.T)
            except:
                print ("Try again the sound of the audio was not clear")

# %%
mysptotal(p)
# Out:
#                            0
# name_of_audio          E1_P4
# number_ of_syllables     106
# number_of_pauses          10
# rate_of_speech             4
# articulation_rate          5
# speaking_duration         21
# original_duration         30
# balance                  0.7
# f0_mean               190.29
# f0_std                 52.83
# f0_median              197.5
# f0_min                    77
# f0_max                   385
# f0_quantile25            171
# f0_quan75                221
#                              0
# name_of_audio         S13_P4_f
# number_ of_syllables        94
# number_of_pauses             6
# rate_of_speech               4
# articulation_rate            5
# speaking_duration         19.9
# original_duration         24.3
# balance                    0.8
# f0_mean                 271.53
# f0_std                   47.74
# f0_median                269.6
# f0_min                      90
# f0_max                     423
# f0_quantile25              239
# f0_quan75                  301
#                             0
# name_of_audio         S1_P4_F
# number_ of_syllables      107
# number_of_pauses            1
# rate_of_speech              4
# articulation_rate           4
# speaking_duration        23.8
# original_duration        26.7
# balance                   0.9
# f0_mean                264.69
# f0_std                  43.45
# f0_median               252.8
# f0_min                    117
# f0_max                    409
# f0_quantile25             235
# f0_quan75                 301
#                             0
# name_of_audio         S2_P4_F
# number_ of_syllables       91
# number_of_pauses            6
# rate_of_speech              3
# articulation_rate           4
# speaking_duration        21.9
# original_duration        28.4
# balance                   0.8
# f0_mean                260.82
# f0_std                  59.07
# f0_median                 249
# f0_min                     79
# f0_max                    423
# f0_quantile25             218
# f0_quan75                 300
#                              0
# name_of_audio         S30_P4_f
# number_ of_syllables        89
# number_of_pauses             3
# rate_of_speech               3
# articulation_rate            4
# speaking_duration         24.6
# original_duration         26.5
# balance                    0.9
# f0_mean                 217.13
# f0_std                   56.51
# f0_median                213.5
# f0_min                      74
# f0_max                     398
# f0_quantile25              185
# f0_quan75                  255
#                             0
# name_of_audio         S33_P4_
# number_ of_syllables       85
# number_of_pauses           10
# rate_of_speech              3
# articulation_rate           4
# speaking_duration        20.9
# original_duration        27.1
# balance                   0.8
# f0_mean                246.15
# f0_std                  63.06
# f0_median               237.3
# f0_min                     80
# f0_max                    412
# f0_quantile25             217
# f0_quan75                 291
#                             0
# name_of_audio         S3_P4_F
# number_ of_syllables      111
# number_of_pauses            8
# rate_of_speech              3
# articulation_rate           4
# speaking_duration        26.5
# original_duration          34
# balance                   0.8
# f0_mean                232.78
# f0_std                  63.61
# f0_median               219.6
# f0_min                     80
# f0_max                    419
# f0_quantile25             200
# f0_quan75                 281
#                             0
# name_of_audio         S3_P5_F
# number_ of_syllables      190
# number_of_pauses           22
# rate_of_speech              3
# articulation_rate           4
# speaking_duration        48.2
# original_duration        66.9
# balance                   0.7
# f0_mean                220.47
# f0_std                  53.68
# f0_median                 220
# f0_min                     71
# f0_max                    410
# f0_quantile25             190
# f0_quan75                 250
#                              0
# name_of_audio         s40_p4_m
# number_ of_syllables        89
# number_of_pauses             8
# rate_of_speech               3
# articulation_rate            4
# speaking_duration           22
# original_duration         28.7
# balance                    0.8
# f0_mean                 154.95
# f0_std                   25.86
# f0_median                148.7
# f0_min                      99
# f0_max                     249
# f0_quantile25              134
# f0_quan75                  173
#                              0
# name_of_audio         s41_p4_f
# number_ of_syllables        87
# number_of_pauses             4
# rate_of_speech               3
# articulation_rate            4
# speaking_duration         21.7
# original_duration           25
# balance                    0.9
# f0_mean                 209.35
# f0_std                   49.31
# f0_median                202.4
# f0_min                      74
# f0_max                     396
# f0_quantile25              180
# f0_quan75                  232
#                              0
# name_of_audio         s45_p4_f
# number_ of_syllables        89
# number_of_pauses             4
# rate_of_speech               4
# articulation_rate            4
# speaking_duration         21.1
# original_duration         24.2
# balance                    0.9
# f0_mean                 218.57
# f0_std                   58.55
# f0_median                211.3
# f0_min                      77
# f0_max                     397
# f0_quantile25              171
# f0_quan75                  262
#                              0
# name_of_audio         s47_p4_m
# number_ of_syllables        89
# number_of_pauses             7
# rate_of_speech               3
# articulation_rate            4
# speaking_duration         20.5
# original_duration         25.5
# balance                    0.8
# f0_mean                 141.66
# f0_std                    16.6
# f0_median                140.4
# f0_min                      81
# f0_max                     312
# f0_quantile25              133
# f0_quan75                  148
#                              0
# name_of_audio         S57_P4_F
# number_ of_syllables        99
# number_of_pauses             3
# rate_of_speech               4
# articulation_rate            5
# speaking_duration         20.9
# original_duration         23.9
# balance                    0.9
# f0_mean                 220.74
# f0_std                   57.12
# f0_median                195.8
# f0_min                      89
# f0_max                     399
# f0_quantile25              182
# f0_quan75                  245
#                             0
# name_of_audio         S6_P4_F
# number_ of_syllables       74
# number_of_pauses            5
# rate_of_speech              3
# articulation_rate           4
# speaking_duration        17.5
# original_duration        23.7
# balance                   0.7
# f0_mean                217.05
# f0_std                  77.61
# f0_median               218.6
# f0_min                     79
# f0_max                    372
# f0_quantile25             135
# f0_quan75                 290

# %%
df_meal = pd.read_csv('my_new_file.csv') 
df_meal.head()
# Out:
#    number_of_syllables  number_of_pauses  rate_of_speech  articulation_rate  \
# 0                  106                10               4                  5
# 1                   94                 6               4                  5
# 2                  107                 1               4                  4
# 3                   91                 6               3                  4
# 4                   89                 3               3                  4
#
#    speaking_duration  original_duration  balance  f0_mean  f0_std  f0_median  \
# 0               21.0               30.0      0.7   190.29   52.83      197.5
# 1               19.9               24.3      0.8   271.53   47.74      269.6
# 2               23.8               26.7      0.9   264.69   43.45      252.8
# 3               21.9               28.4      0.8   260.82   59.07      249.0
# 4               24.6               26.5      0.9   217.13   56.51      213.5
#
#    f0_min  f0_max  f0_quantile25  f0_quan75  \
# 0      77     385            171        221
# 1      90     423            239        301
# 2     117     409            235        301
# 3      79     423            218        300
# 4      74     398            185        255
#
#    Pronunciation_posteriori_probability_score_percentage name_of_audio
# 0                                              95.06         E1_P4.wav
# 1                                             100.00      S13_P4_f.wav
# 2                                              95.07       S1_P4_F.wav
# 3                                              85.14       S2_P4_F.wav
# 4                                              90.05      S30_P4_f.wav

# %% [markdown]
# #### Audio triming using AUDITOK library

# %%
# !pip install auditok
# Out:
# Requirement already satisfied: auditok in c:\users\venusha\anaconda3\envs\fyp_project\lib\site-packages (0.2.0)

# %%
import auditok

# split returns a generator of AudioRegion objects
audio_regions = auditok.split(
    "E1_P4.wav",
    min_dur=0.2,     # minimum duration of a valid audio event in seconds
    max_dur=4,       # maximum duration of an event
    max_silence=0.3, # maximum duration of tolerated continuous silence within an event
    energy_threshold=55 # threshold of detection
)

for i, r in enumerate(audio_regions):

    # Regions returned by `split` have 'start' and 'end' metadata fields
    print("Region {i}: {r.meta.start:.3f}s -- {r.meta.end:.3f}s".format(i=i, r=r))

    # play detection
    # r.play(progress_bar=True)

    # region's metadata can also be used with the `save` method
    # (no need to explicitly specify region's object and `format` arguments)
    filename = r.save("region_{meta.start:.3f}-{meta.end:.3f}.wav")
    print("region saved as: {}".format(filename))
# Out:
# Region 0: 2.500s -- 5.850s
# region saved as: region_2.500-5.850.wav
# Region 1: 5.900s -- 9.650s
# region saved as: region_5.900-9.650.wav
# Region 2: 9.750s -- 11.700s
# region saved as: region_9.750-11.700.wav
# Region 3: 12.400s -- 15.700s
# region saved as: region_12.400-15.700.wav
# Region 4: 16.000s -- 18.400s
# region saved as: region_16.000-18.400.wav
# Region 5: 18.450s -- 18.850s
# region saved as: region_18.450-18.850.wav
# Region 6: 19.050s -- 23.050s
# region saved as: region_19.050-23.050.wav
# Region 7: 23.250s -- 24.700s
# region saved as: region_23.250-24.700.wav
# Region 8: 24.800s -- 26.000s
# region saved as: region_24.800-26.000.wav
# Region 9: 26.150s -- 26.600s
# region saved as: region_26.150-26.600.wav
# Region 10: 28.500s -- 28.850s
# region saved as: region_28.500-28.850.wav

# %%
import auditok 
import cv2
import matplotlib.image as mtimg
audioFileName = "E1_P4.wav"

region = auditok.load(audioFileName) # returns an AudioRegion object
regions = region.split_and_plot() # or just region.splitp()

# %%
## get every audio file region create

# import auditok 
# import cv2

# dir_lists = os.listdir('au/')
# for audioFileName in dir_lists:
#     m = audioFileName.split('.')[0]
#     sound=p+"/"+"au"+"/"+m+".wav"
# #     print(sound)
#     region = auditok.load(sound) # returns an AudioRegion object
#     regions = region.split_and_plot() # or just region.splitp()
  
#     # print(regions)
#     audioCount = 0
#     for i in regions:    
#         audioCount = audioCount+i.duration
#     print(format(audioCount, '.3f'), audioFileName)

# %%
p = r"E:/jupyter_project/FYP_1.1_pro"

# %%
import auditok 
import cv2
extracted_features=[]

dir_lists = os.listdir('au/')
for audioFileName in dir_lists:
    m = audioFileName.split('.')[0]
    sound=p+"/"+"au"+"/"+m+".wav"
#     print(sound)
    region = auditok.load(sound) # returns an AudioRegion object
    regions = region.split_and_plot() # or just region.splitp()
  
    # print(regions)
    audioCount = 0
    for i in regions:    
        audioCount = audioCount+i.duration
#     print(format(audioCount, '.3f'), audioFileName)
    arrData = [audioFileName, format(audioCount, '.3f')]
    extracted_features.append(arrData)
    print(arrData)
    dff = pd.DataFrame(extracted_features,columns=("name_of_audio","speaking_time"))
    #     print(arrarOfData)
    dff.to_csv('audio_speaking.csv',index=False)
    plt.savefig()
# Out:
# ['E1_P4.wav', '25.026']
# ['S1_P4_F.wav', '25.650']
# ['S2_P4_F.wav', '24.050']
# ['S3_P4_F.wav', '30.550']
# ['S3_P5_F.wav', '55.750']
# ['S6_P4_F.wav', '20.950']

# %%
import wave
import contextlib
fname = 'E1_P4.wav'
with contextlib.closing(wave.open(fname,'r')) as f:
    frames = f.getnframes()
    rate = f.getframerate()
    duration = frames / float(rate)
    print(duration)

# %%
import scipy
from scipy.io import wavfile

# %%
# Method 3
import scipy
from scipy.io import wavfile
  
# function to convert the information into 
# some readable format
def output_duration(length):
    hours = length // 3600  # calculate in hours
    length %= 3600
    mins = length // 60  # calculate in minutes
    length %= 60
    seconds = length  # calculate in seconds
  
    return hours, mins, seconds
  
# sample_rate holds the sample rate of the wav file
# in (sample/sec) format
# data is the numpy array that consists
# of actual data read from the wav file
sample_rate, data = wavfile.read('E1_P4.wav')
  
len_data = len(data)  # holds length of the numpy array
  
t = len_data / sample_rate  # returns duration but in floats
  
hours, mins, seconds = output_duration(int(t))
print('Total Duration: {}:{}:{}'.format(hours, mins, seconds))
# Out:
# Total Duration: 0:0:40

# %%
# def myspsyl(p):
#     """
#     Detect and count number of syllables
#     """
#     z2 = run_praat_file(p)
#     z3=int(z2[0]) # will be the integer number 10
#     z4=float(z2[3]) # will be the floating point number 8.3
#     print ("number_ of_syllables=",z3)
#     return z3

# %%
# # Detect and count number of syllables
# myspsyl(p)

# %%
def mysppaus(p):
    """
    Detect and count number of fillers and pauses
    """
    dir_list = os.listdir('myprosody/dataset/audioFiles/')
    # print(dir_list)
    for dir_list in dir_list:
        file_format = dir_list.split('.')[1]
    #     print(file_format)
        if(file_format == "wav"):
            m = dir_list.split('.')[0]
            sound=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"+m+".wav"
            sourcerun=p+"/"+"myprosody"+"/"+"dataset"+"/"+"essen"+"/"+"myspsolution.praat"
            path=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+ "/"

            try:
                objects= run_file(sourcerun, -20, 2, 0.3, "yes",sound,path, 80, 400, 0.01, capture_output=True)
#                 print (objects[0]) # This will print the info from the sound object, and objects[0] is a parselmouth.Sound object
                z1=str( objects[1]) # This will print the info from the textgrid object, and objects[1] is a parselmouth.Data object with a TextGrid inside
                z2=z1.strip().split()
                z3=int(z2[1]) # will be the integer number 10
                z4=float(z2[3]) # will be the floating point number 8.3
                print ("number_of_pauses=",z3)
            except:
                print ("Try again the sound of the audio was not clear")

# %%
# Detect and count number of fillers and pauses
mysppaus(p)
# Out:
# number_of_pauses= 10
# number_of_pauses= 1
# number_of_pauses= 6
# number_of_pauses= 8
# number_of_pauses= 22
# number_of_pauses= 5

# %%
def myspsr(p):
    """
    Measure the rate of speech (speed)
    """
    dir_list = os.listdir('myprosody/dataset/audioFiles/')
    # print(dir_list)
    for dir_list in dir_list:
        file_format = dir_list.split('.')[1]
    #     print(file_format)
        if(file_format == "wav"):
            m = dir_list.split('.')[0]
            sound=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"+m+".wav"
            sourcerun=p+"/"+"myprosody"+"/"+"dataset"+"/"+"essen"+"/"+"myspsolution.praat"
            path=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"

            try:
                objects= run_file(sourcerun, -20, 2, 0.3, "yes",sound,path, 80, 400, 0.01, capture_output=True)
#                 print (objects[0]) # This will print the info from the sound object, and objects[0] is a parselmouth.Sound object
                z1=str( objects[1]) # This will print the info from the textgrid object, and objects[1] is a parselmouth.Data object with a TextGrid inside
                z2=z1.strip().split()
                z3=int(z2[2]) # will be the integer number 10
                z4=float(z2[3]) # will be the floating point number 8.3
                print ("rate_of_speech=",z3,"# syllables/sec original duration")
            except:
                print ("Try again the sound of the audio was not clear")

# %%
#   Measure the rate of speech (speed)
myspsr(p)
# Out:
# rate_of_speech= 4 # syllables/sec original duration
# rate_of_speech= 4 # syllables/sec original duration
# rate_of_speech= 3 # syllables/sec original duration
# rate_of_speech= 3 # syllables/sec original duration
# rate_of_speech= 3 # syllables/sec original duration
# rate_of_speech= 3 # syllables/sec original duration

# %%
def myspatc(p):
    """
    Measure the articulation (speed)
    """
    dir_list = os.listdir('myprosody/dataset/audioFiles/')
    # print(dir_list)
    for dir_list in dir_list:
        file_format = dir_list.split('.')[1]
    #     print(file_format)
        if(file_format == "wav"):
            m = dir_list.split('.')[0]
            sound=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"+m+".wav"
            sourcerun=p+"/"+"myprosody"+"/"+"dataset"+"/"+"essen"+"/"+"myspsolution.praat"
            path=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"

            try:
                objects= run_file(sourcerun, -20, 2, 0.3, "yes",sound,path, 80, 400, 0.01, capture_output=True)
#                 print (objects[0]) # This will print the info from the sound object, and objects[0] is a parselmouth.Sound object
                z1=str( objects[1]) # This will print the info from the textgrid object, and objects[1] is a parselmouth.Data object with a TextGrid inside
                z2=z1.strip().split()         
                z3=int(z2[3]) # will be the integer number 10
                z4=float(z2[3]) # will be the floating point number 8.3
                print ("articulation_rate=",z3,"# syllables/sec speaking duration")
            except:
                print ("Try again the sound of the audio was not clear")

# %%
# Measure the articulation (speed)
myspatc(p)
# Out:
# articulation_rate= 5 # syllables/sec speaking duration
# articulation_rate= 4 # syllables/sec speaking duration
# articulation_rate= 4 # syllables/sec speaking duration
# articulation_rate= 4 # syllables/sec speaking duration
# articulation_rate= 4 # syllables/sec speaking duration
# articulation_rate= 4 # syllables/sec speaking duration

# %%
def myspst(p):
    """
    Measure speaking time (excl. fillers and pause)
    """
    dir_list = os.listdir('myprosody/dataset/audioFiles/')
    # print(dir_list)
    for dir_list in dir_list:
        file_format = dir_list.split('.')[1]
    #     print(file_format)
        if(file_format == "wav"):
            m = dir_list.split('.')[0]
            sound=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"+m+".wav"
            sourcerun=p+"/"+"myprosody"+"/"+"dataset"+"/"+"essen"+"/"+"myspsolution.praat"
            path=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"

            try:
                objects= run_file(sourcerun, -20, 2, 0.3, "yes",sound,path, 80, 400, 0.01, capture_output=True)
#                 print (objects[0]) # This will print the info from the sound object, and objects[0] is a parselmouth.Sound object
                z1=str( objects[1]) # This will print the info from the textgrid object, and objects[1] is a parselmouth.Data object with a TextGrid inside
                z2=z1.strip().split()          
                z3=int(z2[3]) # will be the integer number 10
                z4=float(z2[4]) # will be the floating point number 8.3
                print ("speaking_duration=",z4,"# sec only speaking duration without pauses")
            except:
                print ("Try again the sound of the audio was not clear")

# %%
# Measure speaking time (excl. fillers and pause)
myspst(p)
# Out:
# speaking_duration= 21.0 # sec only speaking duration without pauses
# speaking_duration= 23.8 # sec only speaking duration without pauses
# speaking_duration= 21.9 # sec only speaking duration without pauses
# speaking_duration= 26.5 # sec only speaking duration without pauses
# speaking_duration= 48.2 # sec only speaking duration without pauses
# speaking_duration= 17.5 # sec only speaking duration without pauses

# %%
def myspod(p):
    """
    Measure total speaking duration (inc. fillers and pauses)
    """
    dir_list = os.listdir('myprosody/dataset/audioFiles/')
    # print(dir_list)
    for dir_list in dir_list:
        file_format = dir_list.split('.')[1]
    #     print(file_format)
        if(file_format == "wav"):
            m = dir_list.split('.')[0]
            sound=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"+m+".wav"
            sourcerun=p+"/"+"myprosody"+"/"+"dataset"+"/"+"essen"+"/"+"myspsolution.praat"
            path=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"

            try:
                objects= run_file(sourcerun, -20, 2, 0.3, "yes",sound,path, 80, 400, 0.01, capture_output=True)
#                 print (objects[0]) # This will print the info from the sound object, and objects[0] is a parselmouth.Sound object
                z1=str( objects[1]) # This will print the info from the textgrid object, and objects[1] is a parselmouth.Data object with a TextGrid inside
                z2=z1.strip().split()         
                z3=int(z2[3]) # will be the integer number 10
                z4=float(z2[5]) # will be the floating point number 8.3
                print ("original_duration=",z4,"# sec total speaking duration with pauses")

            except:
                print ("Try again the sound of the audio was not clear")

# %%
# Measure total speaking duration (inc. fillers and pauses)
myspod(p)
# Out:
# original_duration= 30.0 # sec total speaking duration with pauses
# original_duration= 26.7 # sec total speaking duration with pauses
# original_duration= 28.4 # sec total speaking duration with pauses
# original_duration= 34.0 # sec total speaking duration with pauses
# original_duration= 66.9 # sec total speaking duration with pauses
# original_duration= 23.7 # sec total speaking duration with pauses

# %%
def myspbala(p):
    """
    Measure ratio between speaking duration and total speaking duration
    """
    dir_list = os.listdir('myprosody/dataset/audioFiles/')
    # print(dir_list)
    for dir_list in dir_list:
        file_format = dir_list.split('.')[1]
    #     print(file_format)
        if(file_format == "wav"):
            m = dir_list.split('.')[0]
            sound=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"+m+".wav"
            sourcerun=p+"/"+"myprosody"+"/"+"dataset"+"/"+"essen"+"/"+"myspsolution.praat"
            path=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"

            try:
                objects= run_file(sourcerun, -20, 2, 0.3, "yes",sound,path, 80, 400, 0.01, capture_output=True)
#                 print (objects[0]) # This will print the info from the sound object, and objects[0] is a parselmouth.Sound object
                z1=str( objects[1]) # This will print the info from the textgrid object, and objects[1] is a parselmouth.Data object with a TextGrid inside
                z2=z1.strip().split()       
                z3=int(z2[3]) # will be the integer number 10
                z4=float(z2[6]) # will be the floating point number 8.3
                print ("balance=",z4,"# ratio (speaking duration)/(original duration)")
            except:
                print ("Try again the sound of the audio was not clear")

# %%
#  Measure ratio between speaking duration and total speaking duration
myspbala(p)
# Out:
# balance= 0.7 # ratio (speaking duration)/(original duration)
# balance= 0.9 # ratio (speaking duration)/(original duration)
# balance= 0.8 # ratio (speaking duration)/(original duration)
# balance= 0.8 # ratio (speaking duration)/(original duration)
# balance= 0.7 # ratio (speaking duration)/(original duration)
# balance= 0.7 # ratio (speaking duration)/(original duration)

# %%
def myspf0mean(p):
    """
    Measure fundamental frequency distribution mean
    """
    dir_list = os.listdir('myprosody/dataset/audioFiles/')
    # print(dir_list)
    for dir_list in dir_list:
        file_format = dir_list.split('.')[1]
    #     print(file_format)
        if(file_format == "wav"):
            m = dir_list.split('.')[0]
            sound=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"+m+".wav"
            sourcerun=p+"/"+"myprosody"+"/"+"dataset"+"/"+"essen"+"/"+"myspsolution.praat"
            path=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"

            try:
                objects= run_file(sourcerun, -20, 2, 0.3, "yes",sound,path, 80, 400, 0.01, capture_output=True)
#                 print (objects[0]) # This will print the info from the sound object, and objects[0] is a parselmouth.Sound object
                z1=str( objects[1]) # This will print the info from the textgrid object, and objects[1] is a parselmouth.Data object with a TextGrid inside
                z2=z1.strip().split()          
                z3=int(z2[3]) # will be the integer number 10
                z4=float(z2[7]) # will be the floating point number 8.3
                print ("f0_mean=",z4,"# Hz global mean of fundamental frequency distribution")
            except:
                print ("Try again the sound of the audio was not clear")

# %%
# Measure fundamental frequency distribution mean
myspf0mean(p)
# Out:
# f0_mean= 190.29 # Hz global mean of fundamental frequency distribution
# f0_mean= 264.69 # Hz global mean of fundamental frequency distribution
# f0_mean= 260.82 # Hz global mean of fundamental frequency distribution
# f0_mean= 232.78 # Hz global mean of fundamental frequency distribution
# f0_mean= 220.47 # Hz global mean of fundamental frequency distribution
# f0_mean= 217.05 # Hz global mean of fundamental frequency distribution

# %%
def myspf0sd(p):
    """
    Measure fundamental frequency distribution SD
    """
    dir_list = os.listdir('myprosody/dataset/audioFiles/')
    # print(dir_list)
    for dir_list in dir_list:
        file_format = dir_list.split('.')[1]
    #     print(file_format)
        if(file_format == "wav"):
            m = dir_list.split('.')[0]
            sound=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"+m+".wav"
            sourcerun=p+"/"+"myprosody"+"/"+"dataset"+"/"+"essen"+"/"+"myspsolution.praat"
            path=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"

            try:
                objects= run_file(sourcerun, -20, 2, 0.3, "yes",sound,path, 80, 400, 0.01, capture_output=True)
#                 print (objects[0]) # This will print the info from the sound object, and objects[0] is a parselmouth.Sound object
                z1=str( objects[1]) # This will print the info from the textgrid object, and objects[1] is a parselmouth.Data object with a TextGrid inside
                z2=z1.strip().split()        
                z3=int(z2[3]) # will be the integer number 10
                z4=float(z2[8]) # will be the floating point number 8.3
                print ("f0_SD=",z4,"# Hz global standard deviation of fundamental frequency distribution")
            except:
                print ("Try again the sound of the audio was not clear")

# %%
# Measure fundamental frequency distribution SD
myspf0sd(p)
# Out:
# f0_SD= 52.83 # Hz global standard deviation of fundamental frequency distribution
# f0_SD= 43.45 # Hz global standard deviation of fundamental frequency distribution
# f0_SD= 59.07 # Hz global standard deviation of fundamental frequency distribution
# f0_SD= 63.61 # Hz global standard deviation of fundamental frequency distribution
# f0_SD= 53.68 # Hz global standard deviation of fundamental frequency distribution
# f0_SD= 77.61 # Hz global standard deviation of fundamental frequency distribution

# %%
def myspf0med(p):
    """
    Measure fundamental frequency distribution median
    """
    dir_list = os.listdir('myprosody/dataset/audioFiles/')
    # print(dir_list)
    for dir_list in dir_list:
        file_format = dir_list.split('.')[1]
    #     print(file_format)
        if(file_format == "wav"):
            m = dir_list.split('.')[0]
            sound=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"+m+".wav"
            sourcerun=p+"/"+"myprosody"+"/"+"dataset"+"/"+"essen"+"/"+"myspsolution.praat"
            path=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"

            try:
                objects= run_file(sourcerun, -20, 2, 0.3, "yes",sound,path, 80, 400, 0.01, capture_output=True)
#                 print (objects[0]) # This will print the info from the sound object, and objects[0] is a parselmouth.Sound object
                z1=str( objects[1]) # This will print the info from the textgrid object, and objects[1] is a parselmouth.Data object with a TextGrid inside
                z2=z1.strip().split()     
                z3=int(z2[3]) # will be the integer number 10
                z4=float(z2[9]) # will be the floating point number 8.3
                print ("f0_MD=",z4,"# Hz global median of fundamental frequency distribution")
            except:
                print ("Try again the sound of the audio was not clear")

# %%
# Measure fundamental frequency distribution median
myspf0med(p)
# Out:
# f0_MD= 197.5 # Hz global median of fundamental frequency distribution
# f0_MD= 252.8 # Hz global median of fundamental frequency distribution
# f0_MD= 249.0 # Hz global median of fundamental frequency distribution
# f0_MD= 219.6 # Hz global median of fundamental frequency distribution
# f0_MD= 220.0 # Hz global median of fundamental frequency distribution
# f0_MD= 218.6 # Hz global median of fundamental frequency distribution

# %%
def myspf0min(p):
    """
    Measure fundamental frequency distribution minimum
    """
    dir_list = os.listdir('myprosody/dataset/audioFiles/')
    # print(dir_list)
    for dir_list in dir_list:
        file_format = dir_list.split('.')[1]
    #     print(file_format)
        if(file_format == "wav"):
            m = dir_list.split('.')[0]
            sound=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"+m+".wav"
            sourcerun=p+"/"+"myprosody"+"/"+"dataset"+"/"+"essen"+"/"+"myspsolution.praat"
            path=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"

            try:
                objects= run_file(sourcerun, -20, 2, 0.3, "yes",sound,path, 80, 400, 0.01, capture_output=True)
#                 print (objects[0]) # This will print the info from the sound object, and objects[0] is a parselmouth.Sound object
                z1=str( objects[1]) # This will print the info from the textgrid object, and objects[1] is a parselmouth.Data object with a TextGrid inside
                z2=z1.strip().split()   
                z3=int(z2[10]) # will be the integer number 10
                z4=float(z2[10]) # will be the floating point number 8.3
                print ("f0_min=",z3,"# Hz global minimum of fundamental frequency distribution")
            except:
                print ("Try again the sound of the audio was not clear")

# %%
# Measure fundamental frequency distribution minimum
myspf0min(p)
# Out:
# f0_min= 77 # Hz global minimum of fundamental frequency distribution
# f0_min= 117 # Hz global minimum of fundamental frequency distribution
# f0_min= 79 # Hz global minimum of fundamental frequency distribution
# f0_min= 80 # Hz global minimum of fundamental frequency distribution
# f0_min= 71 # Hz global minimum of fundamental frequency distribution
# f0_min= 79 # Hz global minimum of fundamental frequency distribution

# %%
def myspf0max(p):
    """
    Measure fundamental frequency distribution maximum
    """
    dir_list = os.listdir('myprosody/dataset/audioFiles/')
    # print(dir_list)
    for dir_list in dir_list:
        file_format = dir_list.split('.')[1]
    #     print(file_format)
        if(file_format == "wav"):
            m = dir_list.split('.')[0]
            sound=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"+m+".wav"
            sourcerun=p+"/"+"myprosody"+"/"+"dataset"+"/"+"essen"+"/"+"myspsolution.praat"
            path=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"

            try:
                objects= run_file(sourcerun, -20, 2, 0.3, "yes",sound,path, 80, 400, 0.01, capture_output=True)
#                 print (objects[0]) # This will print the info from the sound object, and objects[0] is a parselmouth.Sound object
                z1=str( objects[1]) # This will print the info from the textgrid object, and objects[1] is a parselmouth.Data object with a TextGrid inside
                z2=z1.strip().split()         
                z3=int(z2[11]) # will be the integer number 10
                z4=float(z2[11]) # will be the floating point number 8.3
                print ("f0_max=",z3,"# Hz global maximum of fundamental frequency distribution")
            except:
                print ("Try again the sound of the audio was not clear")

# %%
# Measure fundamental frequency distribution maximum
myspf0max(p)
# Out:
# f0_max= 385 # Hz global maximum of fundamental frequency distribution
# f0_max= 409 # Hz global maximum of fundamental frequency distribution
# f0_max= 423 # Hz global maximum of fundamental frequency distribution
# f0_max= 419 # Hz global maximum of fundamental frequency distribution
# f0_max= 410 # Hz global maximum of fundamental frequency distribution
# f0_max= 372 # Hz global maximum of fundamental frequency distribution

# %%
def myspf0q25(p):
    """
    Measure 25th quantile fundamental frequency distribution
    """
    dir_list = os.listdir('myprosody/dataset/audioFiles/')
    # print(dir_list)
    for dir_list in dir_list:
        file_format = dir_list.split('.')[1]
    #     print(file_format)
        if(file_format == "wav"):
            m = dir_list.split('.')[0]
            sound=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"+m+".wav"
            sourcerun=p+"/"+"myprosody"+"/"+"dataset"+"/"+"essen"+"/"+"myspsolution.praat"
            path=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"

            try:
                objects= run_file(sourcerun, -20, 2, 0.3, "yes",sound,path, 80, 400, 0.01, capture_output=True)
#                 print (objects[0]) # This will print the info from the sound object, and objects[0] is a parselmouth.Sound object
                z1=str( objects[1]) # This will print the info from the textgrid object, and objects[1] is a parselmouth.Data object with a TextGrid inside
                z2=z1.strip().split()         
                z3=int(z2[12]) # will be the integer number 10
                z4=float(z2[11]) # will be the floating point number 8.3
                print ("f0_quan25=",z3,"# Hz global 25th quantile of fundamental frequency distribution")
            except:
                print ("Try again the sound of the audio was not clear")

# %%
# Measure 25th quantile fundamental frequency distribution
myspf0q25(p)
# Out:
# f0_quan25= 171 # Hz global 25th quantile of fundamental frequency distribution
# f0_quan25= 235 # Hz global 25th quantile of fundamental frequency distribution
# f0_quan25= 218 # Hz global 25th quantile of fundamental frequency distribution
# f0_quan25= 200 # Hz global 25th quantile of fundamental frequency distribution
# f0_quan25= 190 # Hz global 25th quantile of fundamental frequency distribution
# f0_quan25= 135 # Hz global 25th quantile of fundamental frequency distribution

# %%
def myspf0q75(p):
    """
    Measure 75th quantile fundamental frequency distribution
    """
    dir_list = os.listdir('myprosody/dataset/audioFiles/')
    # print(dir_list)
    for dir_list in dir_list:
        file_format = dir_list.split('.')[1]
    #     print(file_format)
        if(file_format == "wav"):
            m = dir_list.split('.')[0]
            sound=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"+m+".wav"
            sourcerun=p+"/"+"myprosody"+"/"+"dataset"+"/"+"essen"+"/"+"myspsolution.praat"
            path=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"

            try:
                objects= run_file(sourcerun, -20, 2, 0.3, "yes",sound,path, 80, 400, 0.01, capture_output=True)
#                 print (objects[0]) # This will print the info from the sound object, and objects[0] is a parselmouth.Sound object
                z1=str( objects[1]) # This will print the info from the textgrid object, and objects[1] is a parselmouth.Data object with a TextGrid inside
                z2=z1.strip().split() 
                z3=int(z2[13]) # will be the integer number 10
                z4=float(z2[11]) # will be the floating point number 8.3
                print ("f0_quan75=",z3,"# Hz global 75th quantile of fundamental frequency distribution")
            except:
                print ("Try again the sound of the audio was not clear")

# %%
# Measure 75th quantile fundamental frequency distribution
myspf0q75(p)
# Out:
# f0_quan75= 221 # Hz global 75th quantile of fundamental frequency distribution
# f0_quan75= 301 # Hz global 75th quantile of fundamental frequency distribution
# f0_quan75= 300 # Hz global 75th quantile of fundamental frequency distribution
# f0_quan75= 281 # Hz global 75th quantile of fundamental frequency distribution
# f0_quan75= 250 # Hz global 75th quantile of fundamental frequency distribution
# f0_quan75= 290 # Hz global 75th quantile of fundamental frequency distribution

# %%
def mysptotal(p):
    """
    Overview
    """
    dir_list = os.listdir('myprosody/dataset/audioFiles/')
    # print(dir_list)
    for dir_list in dir_list:
        file_format = dir_list.split('.')[1]
    #     print(file_format)
        if(file_format == "wav"):
            m = dir_list.split('.')[0]
            sound=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"+m+".wav"
            sourcerun=p+"/"+"myprosody"+"/"+"dataset"+"/"+"essen"+"/"+"myspsolution.praat"
            path=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"
            
            try:
                objects= run_file(sourcerun, -20, 2, 0.3, "yes",sound,path, 80, 400, 0.01, capture_output=True)
#                 print (objects[0]) # This will print the info from the sound object, and objects[0] is a parselmouth.Sound object
                z1=str( objects[1]) # This will print the info from the textgrid object, and objects[1] is a parselmouth.Data object with a TextGrid inside
                z2=z1.strip().split()          
                z3=np.array(z2)
                z4=np.array(z3)[np.newaxis]
                z5=z4.T
                dataset=pd.DataFrame({"name_of_audio":m,"number_ of_syllables":z5[0,:],"number_of_pauses":z5[1,:],"rate_of_speech":z5[2,:],"articulation_rate":z5[3,:],"speaking_duration":z5[4,:],
                        "original_duration":z5[5,:],"balance":z5[6,:],"f0_mean":z5[7,:],"f0_std":z5[8,:],"f0_median":z5[9,:],"f0_min":z5[10,:],"f0_max":z5[11,:],
                        "f0_quantile25":z5[12,:],"f0_quan75":z5[13,:]})
                print (dataset.T)
            except:
                print ("Try again the sound of the audio was not clear")

# %%
#  Overview
mysptotal(p)
# Out:
#                            0
# name_of_audio          E1_P4
# number_ of_syllables     106
# number_of_pauses          10
# rate_of_speech             4
# articulation_rate          5
# speaking_duration         21
# original_duration         30
# balance                  0.7
# f0_mean               190.29
# f0_std                 52.83
# f0_median              197.5
# f0_min                    77
# f0_max                   385
# f0_quantile25            171
# f0_quan75                221
#                             0
# name_of_audio         S1_P4_F
# number_ of_syllables      107
# number_of_pauses            1
# rate_of_speech              4
# articulation_rate           4
# speaking_duration        23.8
# original_duration        26.7
# balance                   0.9
# f0_mean                264.69
# f0_std                  43.45
# f0_median               252.8
# f0_min                    117
# f0_max                    409
# f0_quantile25             235
# f0_quan75                 301
#                             0
# name_of_audio         S2_P4_F
# number_ of_syllables       91
# number_of_pauses            6
# rate_of_speech              3
# articulation_rate           4
# speaking_duration        21.9
# original_duration        28.4
# balance                   0.8
# f0_mean                260.82
# f0_std                  59.07
# f0_median                 249
# f0_min                     79
# f0_max                    423
# f0_quantile25             218
# f0_quan75                 300
#                             0
# name_of_audio         S3_P4_F
# number_ of_syllables      111
# number_of_pauses            8
# rate_of_speech              3
# articulation_rate           4
# speaking_duration        26.5
# original_duration          34
# balance                   0.8
# f0_mean                232.78
# f0_std                  63.61
# f0_median               219.6
# f0_min                     80
# f0_max                    419
# f0_quantile25             200
# f0_quan75                 281
#                             0
# name_of_audio         S3_P5_F
# number_ of_syllables      190
# number_of_pauses           22
# rate_of_speech              3
# articulation_rate           4
# speaking_duration        48.2
# original_duration        66.9
# balance                   0.7
# f0_mean                220.47
# f0_std                  53.68
# f0_median                 220
# f0_min                     71
# f0_max                    410
# f0_quantile25             190
# f0_quan75                 250
#                             0
# name_of_audio         S6_P4_F
# number_ of_syllables       74
# number_of_pauses            5
# rate_of_speech              3
# articulation_rate           4
# speaking_duration        17.5
# original_duration        23.7
# balance                   0.7
# f0_mean                217.05
# f0_std                  77.61
# f0_median               218.6
# f0_min                     79
# f0_max                    372
# f0_quantile25             135
# f0_quan75                 290

# %%
def mysppron(p):
    """
    Pronunciation posteriori probability score percentage
    """
    dir_list = os.listdir('myprosody/dataset/audioFiles/')
    # print(dir_list)
    for dir_list in dir_list:
        file_format = dir_list.split('.')[1]
    #     print(file_format)
        if(file_format == "wav"):
            m = dir_list.split('.')[0]
            sound=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"+m+".wav"
            sourcerun=p+"/"+"myprosody"+"/"+"dataset"+"/"+"essen"+"/"+"myspsolution.praat"
            path=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"

            try:
                objects= run_file(sourcerun, -20, 2, 0.3, "yes",sound,path, 80, 400, 0.01, capture_output=True)
#                 print (objects[0]) # This will print the info from the sound object, and objects[0] is a parselmouth.Sound object
                z1=str( objects[1]) # This will print the info from the textgrid object, and objects[1] is a parselmouth.Data object with a TextGrid inside
                z2=z1.strip().split()
                z3=int(z2[13]) # will be the integer number 10
                z4=float(z2[14]) # will be the floating point number 8.3
                db= binom.rvs(n=10,p=z4,size=10000)
                a=np.array(db)
                b=np.mean(a)*100/10
                print ("Pronunciation_posteriori_probability_score_percentage= :%.2f" % (b))
            except:
                print ("Try again the sound of the audio was not clear")

# %%
#  Pronunciation posteriori probability score percentage
mysppron(p)
# Out:
# Pronunciation_posteriori_probability_score_percentage= :94.91
# Pronunciation_posteriori_probability_score_percentage= :94.98
# Pronunciation_posteriori_probability_score_percentage= :84.91
# Pronunciation_posteriori_probability_score_percentage= :84.97
# Pronunciation_posteriori_probability_score_percentage= :69.64
# Pronunciation_posteriori_probability_score_percentage= :84.87

# %%
def myspgend(p):
    """
    Gender recognition and mood of speech
    """
    dir_list = os.listdir('myprosody/dataset/audioFiles/')
    # print(dir_list)
    for dir_list in dir_list:
        file_format = dir_list.split('.')[1]
    #     print(file_format)
        if(file_format == "wav"):
            m = dir_list.split('.')[0]
            sound=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"+m+".wav"
            sourcerun=p+"/"+"myprosody"+"/"+"dataset"+"/"+"essen"+"/"+"myspsolution.praat"
            path=p+"/"+"myprosody"+"/"+"dataset"+"/"+"audioFiles"+"/"

            try:
                objects= run_file(sourcerun, -20, 2, 0.3, "yes",sound,path, 80, 400, 0.01, capture_output=True)
#                 print (objects[0]) # This will print the info from the sound object, and objects[0] is a parselmouth.Sound object
                z1=str( objects[1]) # This will print the info from the textgrid object, and objects[1] is a parselmouth.Data object with a TextGrid inside
                z2=z1.strip().split()
        
                z3=float(z2[8]) # will be the integer number 10
                z4=float(z2[7]) # will be the floating point number 8.3
                if z4<=114:
                    g=101
                    j=3.4
                elif z4>114 and z4<=135:
                    g=128
                    j=4.35
                elif z4>135 and z4<=163:
                    g=142
                    j=4.85
                elif z4>163 and z4<=197:
                    g=182
                    j=2.7
                elif z4>197 and z4<=226:
                    g=213
                    j=4.5
                elif z4>226:
                    g=239
                    j=5.3
                else:
                    print("Voice not recognized")
                    exit()
                def teset(a,b,c,d):
                    d1=np.random.wald(a, 1, 1000)
                    d2=np.random.wald(b,1,1000)
                    d3=ks_2samp(d1, d2)
                    c1=np.random.normal(a,c,1000)
                    c2=np.random.normal(b,d,1000)
                    c3=ttest_ind(c1,c2)
                    y=([d3[0],d3[1],abs(c3[0]),c3[1]])
                    return y
                nn=0
                mm=teset(g,j,z4,z3)
                while (mm[3]>0.05 and mm[0]>0.04 or nn<5):
                    mm=teset(g,j,z4,z3)
                    nn=nn+1
                nnn=nn
                if mm[3]<=0.09:
                    mmm=mm[3]
                else:
                    mmm=0.35
                if z4>97 and z4<=114:
                    print("a Male, mood of speech: Showing no emotion, normal, p-value/sample size= :%.2f" % (mmm), (nnn))
                elif z4>114 and z4<=135:
                    print("a Male, mood of speech: Reading, p-value/sample size= :%.2f" % (mmm), (nnn))
                elif z4>135 and z4<=163:
                    print("a Male, mood of speech: speaking passionately, p-value/sample size= :%.2f" % (mmm), (nnn))
                elif z4>163 and z4<=197:
                    print("a female, mood of speech: Showing no emotion, normal, p-value/sample size= :%.2f" % (mmm), (nnn))
                elif z4>197 and z4<=226:
                    print("a female, mood of speech: Reading, p-value/sample size= :%.2f" % (mmm), (nnn))
                elif z4>226 and z4<=245:
                    print("a female, mood of speech: speaking passionately, p-value/sample size= :%.2f" % (mmm), (nnn))
                else:
                    print("Voice not recognized")
            except:
                print ("Try again the sound of the audio was not clear")

# %%
# Gender recognition and mood of speech
myspgend(p)
# Out:
# a female, mood of speech: Showing no emotion, normal, p-value/sample size= :0.00 5
# Voice not recognized
# Voice not recognized
# a female, mood of speech: speaking passionately, p-value/sample size= :0.00 5
# a female, mood of speech: Reading, p-value/sample size= :0.00 5
# a female, mood of speech: Reading, p-value/sample size= :0.00 5

# %%
# !pip install myprosody
# Out:
# Collecting myprosody
#   Downloading myprosody-20-py3-none-any.whl (18 kB)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\venusha\anaconda3\envs\fyp_project\lib\site-packages (from myprosody) (1.6.2)
# Requirement already satisfied: pickleshare>=0.7.5 in c:\users\venusha\anaconda3\envs\fyp_project\lib\site-packages (from myprosody) (0.7.5)
# Requirement already satisfied: scikit-learn>=0.20.2 in c:\users\venusha\anaconda3\envs\fyp_project\lib\site-packages (from myprosody) (0.24.2)
# Requirement already satisfied: praat-parselmouth>=0.3.2 in c:\users\venusha\anaconda3\envs\fyp_project\lib\site-packages (from myprosody) (0.4.0)
# Requirement already satisfied: numpy>=1.15.2 in c:\users\venusha\anaconda3\envs\fyp_project\lib\site-packages (from myprosody) (1.20.2)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\venusha\anaconda3\envs\fyp_project\lib\site-packages (from myprosody) (1.2.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\venusha\anaconda3\envs\fyp_project\lib\site-packages (from pandas>=0.23.4->myprosody) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\venusha\anaconda3\envs\fyp_project\lib\site-packages (from pandas>=0.23.4->myprosody) (2021.1)
# Requirement already satisfied: six>=1.5 in c:\users\venusha\anaconda3\envs\fyp_project\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.23.4->myprosody) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\venusha\anaconda3\envs\fyp_project\lib\site-packages (from scikit-learn>=0.20.2->myprosody) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\venusha\anaconda3\envs\fyp_project\lib\site-packages (from scikit-learn>=0.20.2->myprosody) (2.1.0)
# Installing collected packages: myprosody
# Successfully installed myprosody-20

# %%
m='E1_P4'
p = r"C:/Users/Dilakshana/new_FYP_project/fyp_1.1_process/myprosody"

# %%
# def myprosody(m,p):
#     """
#     Compared to native speech, here are the prosodic features of your speech
#     """
#     sound=p+"/"+"dataset"+"/"+"audioFiles"+"/"+m+".wav"
#     sourcerun=p+"/"+"dataset"+"/"+"essen"+"/"+"MLTRNL.praat"
#     path=p+"/"+"dataset"+"/"+"audioFiles"+"/"
#     outo=p+"/"+"dataset"+"/"+"datanewchi22.csv"
#     outst=p+"/"+"dataset"+"/"+"datanewchi44.csv"
#     outsy=p+"/"+"dataset"+"/"+"datanewchi33.csv"
#     pa2=p+"/"+"dataset"+"/"+"stats.csv"
#     pa7=p+"/"+"dataset"+"/"+"datanewchi44.csv" 
#     result_array = np.empty((0, 100))
#     files = glob.glob(path)
#     result_array = np.empty((0, 27))
#     try:
#         objects= run_file(sourcerun, -20, 2, 0.3, "yes",sound,path, 80, 400, 0.01, capture_output=True)
#         z1=( objects[1]) # This will print the info from the textgrid object, and objects[1] is a parselmouth.Data object with a TextGrid inside
#         z3=z1.strip().split()
#         z2=np.array([z3])
#         result_array=np.append(result_array,[z3], axis=0)
#         #print(z3)
#         np.savetxt(outo,result_array, fmt='%s',delimiter=',')
#         #Data and features analysis
#         df = pd.read_csv(outo, names = ['avepauseduratin','avelongpause','speakingtot','avenumberofwords','articulationrate','inpro','f1norm','mr','q25','q50','q75','std','fmax','fmin','vowelinx1','vowelinx2','formantmean','formantstd','nuofwrds','npause','ins','fillerratio','xx','xxx','totsco','xxban','speakingrate'],na_values='?')
#         scoreMLdataset=df.drop(['xxx','xxban'], axis=1)
#         scoreMLdataset.to_csv(outst, header=False,index = False)
#         newMLdataset=df.drop(['avenumberofwords','f1norm','inpro','q25','q75','vowelinx1','nuofwrds','npause','xx','totsco','xxban','speakingrate','fillerratio'], axis=1)
#         newMLdataset.to_csv(outsy, header=False,index = False)
#         namess=nms = ['avepauseduratin','avelongpause','speakingtot','articulationrate','mr','q50','std','fmax','fmin','vowelinx2','formantmean','formantstd','ins','xxx']
#         df1 = pd.read_csv(outsy, names = namess)
#         nsns=['average_syll_pause_duration','No._long_pause','speaking_time','ave_No._of_words_in_minutes','articulation_rate','No._words_in_minutes','formants_index','f0_index','f0_quantile_25_index','f0_quantile_50_index','f0_quantile_75_index','f0_std','f0_max','f0_min','No._detected_vowel','perc%._correct_vowel','(f2/f1)_mean','(f2/f1)_std','no._of_words','no._of_pauses','intonation_index','(voiced_syll_count)/(no_of_pause)','TOEFL_Scale_Score','Score_Shannon_index','speaking_rate']
#         dataframe = pd.read_csv(pa2)
#         df55 = pd.read_csv(outst,names=nsns)
#         dataframe=dataframe.values
#         array = df55.values
#         print("Compared to native speech, here are the prosodic features of your speech:")
#         for i in range(25):
#             sl0=dataframe[4:7:1,i+1]
#             score = array[0,i]
#             he=scipy.stats.percentileofscore(sl0, score, kind='strict')
#             if he==0:
#                 he=25
#                 dfout = "%s:\t %f (%s)" %  (nsns[i],he,"% percentile ")
#                 print(dfout)
#             elif he>=25 and he<=75:
#                 dfout = "%s:\t %f (%s)" % (nsns[i],he,"% percentile ")
#                 print(dfout)
#             else:
#                 dfout = "%s:\t (%s)" % (nsns[i],":Out of Range")
#                 print(dfout)
#     except:
#         print ("Try again the sound of the audio was not clear")

# %%
# Compared to native speech, here are the prosodic features of your speech
myprosody(m,p)
# Out:
# Try again the sound of the audio was not clear

# %%
# def mysplev(m,p):
#     """
#     Spoken Language Proficiency Level estimator, 
#     based on Machine Learning models of the prosodic features of your speech
#     """
#     import sys
#     def my_except_hook(exctype, value, traceback):
#         print('There has been an error in the system')
#     sys.excepthook = my_except_hook
#     import warnings
#     if not sys.warnoptions:
#         warnings.simplefilter("ignore")
#     sound=p+"/"+"dataset"+"/"+"audioFiles"+"/"+m+".wav"
#     sourcerun=p+"/"+"dataset"+"/"+"essen"+"/"+"MLTRNL.praat"
#     path=p+"/"+"dataset"+"/"+"audioFiles"+"/"
#     pa1=p+"/"+"dataset"+"/"+"datanewchi23.csv"
#     pa7=p+"/"+"dataset"+"/"+"datanewchi45.csv"
#     pa5=p+"/"+"dataset"+"/"+"datanewchi34.csv"
#     result_array = np.empty((0, 100))
#     ph = sound
#     files = glob.glob(ph)
#     result_array = np.empty((0, 27))
#     try:
#         for soundi in files:
#             objects= run_file(sourcerun, -20, 2, 0.3, "yes", soundi, path, 80, 400, 0.01, capture_output=True)
#             print (objects[0]) # This will print the info from the sound object, and objects[0] is a parselmouth.Sound object
#             z1=( objects[1]) # This will print the info from the textgrid object, and objects[1] is a parselmouth.Data object with a TextGrid inside
#             z3=z1.strip().split()
#             z2=np.array([z3])
#             result_array=np.append(result_array,[z3], axis=0)

#         np.savetxt(pa1,result_array, fmt='%s',delimiter=',')
#         #Data and features analysis 
#         df = pd.read_csv(pa1, names = ['avepauseduratin','avelongpause','speakingtot','avenumberofwords','articulationrate','inpro','f1norm','mr','q25','q50','q75','std','fmax','fmin','vowelinx1','vowelinx2','formantmean','formantstd','nuofwrds','npause','ins','fillerratio','xx','xxx','totsco','xxban','speakingrate'],na_values='?')

#         scoreMLdataset=df.drop(['xxx','xxban'], axis=1)
#         scoreMLdataset.to_csv(pa7, header=False,index = False)
#         newMLdataset=df.drop(['avenumberofwords','f1norm','inpro','q25','q75','vowelinx1','nuofwrds','npause','xx','totsco','xxban','speakingrate','fillerratio'], axis=1)
#         newMLdataset.to_csv(pa5, header=False,index = False)
#         namess=nms = ['avepauseduratin','avelongpause','speakingtot','articulationrate','mr','q50','std','fmax','fmin','vowelinx2','formantmean','formantstd','ins','xxx']
#         df1 = pd.read_csv(pa5,names = namess)
#         df33=df1.drop(['xxx'], axis=1)
#         array = df33.values
#         array=np.log(array)
#         x = array[:,0:13]

#         def myspp(bp,bg):
#             sound=bg+"/"+"dataset"+"/"+"audioFiles"+"/"+bp+".wav"
#             sourcerun=bg+"/"+"dataset"+"/"+"essen"+"/"+"myspsolution.praat"
#             path=bg+"/"+"dataset"+"/"+"audioFiles"+"/"
#             objects= run_file(sourcerun, -20, 2, 0.3, "yes",sound,path, 80, 400, 0.01, capture_output=True)
#             print (objects[0]) # This will print the info from the sound object, and objects[0] is a parselmouth.Sound object
#             z1=str( objects[1]) # This will print the info from the textgrid object, and objects[1] is a parselmouth.Data object with a TextGrid inside
#             z2=z1.strip().split()
#             z3=int(z2[13]) # will be the integer number 10
#             z4=float(z2[14]) # will be the floating point number 8.3
#             db= binom.rvs(n=10,p=z4,size=10000)
#             a=np.array(db)
#             b=np.mean(a)*100/10
#             return b

#         bp=m
#         bg=p
#         bi=myspp(bp,bg)
#         if bi<85:
#             input("Try again, unnatural-sounding speech detected. No further result. Press any key to exit.")
#             exit()

#         filename=p+"/"+"dataset"+"/"+"essen"+"/"+"CART_model.sav"
#         model = pickle.load(open(filename, 'rb'))
#         predictions = model.predict(x)
#         print("58% accuracy    ",predictions)

#         filename=p+"/"+"dataset"+"/"+"essen"+"/"+"KNN_model.sav"
#         model = pickle.load(open(filename, 'rb'))
#         predictions = model.predict(x)
#         print("65% accuracy    ",predictions)

#         filename=p+"/"+"dataset"+"/"+"essen"+"/"+"LDA_model.sav"
#         model = pickle.load(open(filename, 'rb'))
#         predictions = model.predict(x)
#         print("70% accuracy    ",predictions)
    
#         filename=p+"/"+"dataset"+"/"+"essen"+"/"+"LR_model.sav"
#         model = pickle.load(open(filename, 'rb'))
#         predictions = model.predict(x)
#         print("67% accuracy    ",predictions)

#         filename=p+"/"+"dataset"+"/"+"essen"+"/"+"NB_model.sav"
#         model = pickle.load(open(filename, 'rb'))
#         predictions = model.predict(x)
#         print("64% accuracy    ",predictions)

#         filename=p+"/"+"dataset"+"/"+"essen"+"/"+"SVN_model.sav"
#         model = pickle.load(open(filename, 'rb'))
#         predictions = model.predict(x)
#         print("63% accuracy    ",predictions)
#     except:
#         print ("Try again the sound of the audio was not clear")

# %%
# # Spoken Language Proficiency Level estimator, 
# # based on Machine Learning models of the prosodic features of your speech
# mysplev(m,p)

# %%
# def mysplevf(m,p):
#     import sys
#     def my_except_hook(exctype, value, traceback):
#         print('There has been an error in the system')
#     sys.excepthook = my_except_hook
#     import warnings
#     if not sys.warnoptions:
#         warnings.simplefilter("ignore")
#     sound=p+"/"+"dataset"+"/"+"audioFiles"+"/"+m+".wav"
#     sourcerun=p+"/"+"dataset"+"/"+"essen"+"/"+"MLTRNL.praat"
#     path=p+"/"+"dataset"+"/"+"audioFiles"+"/"
#     pa1=p+"/"+"dataset"+"/"+"datanewchi23.csv"
#     pa7=p+"/"+"dataset"+"/"+"datanewchi45.csv"
#     pa5=p+"/"+"dataset"+"/"+"datanewchi34.csv"
#     result_array = np.empty((0, 100))
#     ph = sound
#     files = glob.glob(ph)
#     result_array = np.empty((0, 27))
#     try:
#         for soundi in files:
#             objects= run_file(sourcerun, -20, 2, 0.3, "yes", soundi, path, 80, 400, 0.01, capture_output=True)
#             #print (objects[0]) # This will print the info from the sound object, and objects[0] is a parselmouth.Sound object
#             z1=( objects[1]) # This will print the info from the textgrid object, and objects[1] is a parselmouth.Data object with a TextGrid inside
#             z3=z1.strip().split()
#             z2=np.array([z3])
#             result_array=np.append(result_array,[z3], axis=0)

#         np.savetxt(pa1,result_array, fmt='%s',delimiter=',')
#         #Data and features analysis
#         df = pd.read_csv(pa1, names = ['avepauseduratin','avelongpause','speakingtot','avenumberofwords','articulationrate','inpro','f1norm','mr','q25',
#                                       'q50','q75','std','fmax','fmin','vowelinx1','vowelinx2','formantmean','formantstd','nuofwrds','npause','ins',
#                                       'fillerratio','xx','xxx','totsco','xxban','speakingrate'],na_values='?')

#         scoreMLdataset=df.drop(['xxx','xxban'], axis=1)
#         scoreMLdataset.to_csv(pa7, header=False,index = False)
#         newMLdataset=df.drop(['avenumberofwords','f1norm','inpro','q25','q75','vowelinx1','nuofwrds','npause','xx','totsco','xxban','speakingrate','fillerratio'], axis=1)
#         newMLdataset.to_csv(pa5, header=False,index = False)
#         namess=nms = ['avepauseduratin','avelongpause','speakingtot','articulationrate','mr',
#                                       'q50','std','fmax','fmin','vowelinx2','formantmean','formantstd','ins',
#                                       'xxx']
#         df1 = pd.read_csv(pa5,
#                                 names = namess)
#         df33=df1.drop(['xxx'], axis=1)
#         array = df33.values
#         array=np.log(array)
#         x = array[:,0:13]

#         def myspp(bp,bg):
#           sound=bg+"/"+"dataset"+"/"+"audioFiles"+"/"+bp+".wav"
#           sourcerun=bg+"/"+"dataset"+"/"+"essen"+"/"+"myspsolution.praat"
#           path=bg+"/"+"dataset"+"/"+"audioFiles"+"/"
#           objects= run_file(sourcerun, -20, 2, 0.3, "yes",sound,path, 80, 400, 0.01, capture_output=True)
#           print (objects[0]) # This will print the info from the sound object, and objects[0] is a parselmouth.Sound object
#           z1=str( objects[1]) # This will print the info from the textgrid object, and objects[1] is a parselmouth.Data object with a TextGrid inside
#           z2=z1.strip().split()
#           z3=int(z2[13]) # will be the integer number 10
#           z4=float(z2[14]) # will be the floating point number 8.3
#           db= binom.rvs(n=10,p=z4,size=10000)
#           a=np.array(db)
#           b=np.mean(a)*100/10
#           return b

#         bp=m
#         bg=p
#         bi=myspp(bp,bg)
#         if bi<85:
#             input("Try again, unnatural-sounding speech detected. No further result. Press any key to exit.")
#             exit()

#         filename=p+"/"+"dataset"+"/"+"essen"+"/"+"CART_model.sav"
#         model = pickle.load(open(filename, 'rb'))
#         predictions = model.predict(x)
#         print("58% accuracy    ",predictions)

#         filename=p+"/"+"dataset"+"/"+"essen"+"/"+"KNN_model.sav"
#         model = pickle.load(open(filename, 'rb'))
#         predictions = model.predict(x)
#         print("65% accuracy    ",predictions)

#         filename=p+"/"+"dataset"+"/"+"essen"+"/"+"LDA_model.sav"
#         model = pickle.load(open(filename, 'rb'))
#         predictions = model.predict(x)
#         print("70% accuracy    ",predictions)

#         filename=p+"/"+"dataset"+"/"+"essen"+"/"+"LR_model.sav"
#         model = pickle.load(open(filename, 'rb'))
#         predictions = model.predict(x)
#         print("67% accuracy    ",predictions)

#         filename=p+"/"+"dataset"+"/"+"essen"+"/"+"NB_model.sav"
#         model = pickle.load(open(filename, 'rb'))
#         predictions = model.predict(x)
#         print("64% accuracy    ",predictions)

#         filename=p+"/"+"dataset"+"/"+"essen"+"/"+"SVN_model.sav"
#         model = pickle.load(open(filename, 'rb'))
#         predictions = model.predict(x)
#         print("63% accuracy    ",predictions)
#     except:
#         print ("Try again the sound of the audio was not clear")

# %%
# mysplevf(m,p)
